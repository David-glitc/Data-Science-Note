# %% [markdown]
# # Statistcal Approach

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(2)
a=np.random.normal(100,20,100000)

plt.hist(a,90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.median(a)
# Out:
# 99.90483480017592

# %%
np.mean(a)
# Out:
# 99.93461579192461

# %%
a=np.append(a,[30000])

# %%
np.median(a)
# Out:
# 99.90484784587414

# %%
np.mean(a)
# Out:
# 100.23361345579006

# %%
b=np.random.randint(1,high=10,size=30)
e=np.random.randint(1,high=100,size=30)

d=np.random.randint(1,high=500,size=30)

# %%
b
print(d)
# Out:
# [ 71  64  51 194 263 178  45   7 140  54 379 362 406 384  87 466 197 301
#   26 104 171  68  85 441 431 125 150  83 298 444]

# %%
from scipy import stats

stats.mode(b)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11152\2340764550.py:3: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   stats.mode(b)
# ModeResult(mode=array([8]), count=array([5]))

# %%
plt.scatter(b,d,c='r')
plt.scatter(b,e,c='g')


def predict(b):
    return -5*b+100
fitline = predict(b)

plt.plot(b,fitline, c='b')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
