# %%
import numpy as np 
import matplotlib.pyplot as plt


a=np.random.normal(100,25,10000)
plt.hist(a,50)
plt.show()

# %%
a.std()
# Out:
# 24.974377200401914

# %%
a.mean()
# Out:
# 99.80743904748908
